# %% [markdown]
# PA2 Sandbox Notebook
# ===
#
# A "sandbox" for developing and testing functions in the `src` directory.
#
# Functions are organized in reverse chronological order of development, so that restarting the kernel and reruning to the current cell is as efficient as possible.

# %% [markdown]
# # Installation and Setup
#
# Carefully follow our **[Installation Instructions](README.md#get-started)**.

# %% [markdown]
# ## Import Python Dependencies

# %%
from pathlib import Path

import pandas    as pd
import geopandas as gpd

import warnings

# # geo packages
# from shapely.geometry import Polygon
# import contextily as ctx

# # packages for viz 
# import matplotlib
# import matplotlib.pyplot as plt
# from matplotlib_scalebar.scalebar import ScaleBar
# from  matplotlib.colors import LogNorm

# %%
# Confirm that this repo is in your Python Path
# !conda-develop /Users/aaufdenkampe/Documents/Python/pollution-assessment/src

# %%
# Custom functions for Pollution Assessment
import pollution_assessment as pa
import pollution_assessment.calc
import pollution_assessment.plot

# %% [markdown]
# ## Set Paths and Open Files from Notebook 1

# %%
# Set your project directory to your local folder for your clone of this repository
project_path = Path.cwd().parent
project_path
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/pollution-assessment')

# %%
# Assign relative paths for the data OUTPUT folder.
pa2_data_output_folder = Path('stage2/data_output')

data_output_path = project_path /pa2_data_output_folder

# %% [markdown]
# ## Read Notebook 1 Outputs

# %%
# %%time
# read geometry data from GeoParquet files
reach_gdf = gpd.read_parquet(data_output_path /'reach_gdf.parquet')
catch_gdf = gpd.read_parquet(data_output_path /'catch_gdf.parquet')
# Out:
# CPU times: user 1.13 s, sys: 119 ms, total: 1.25 s
# Wall time: 1.23 s

# %%
# %%time
# read results data from Parquet files
reach_concs_df = pd.read_parquet(data_output_path /'reach_concs_df.parquet')
catch_loads_df = pd.read_parquet(data_output_path /'catch_loads_df.parquet')
# Out:
# CPU times: user 81.5 ms, sys: 19.5 ms, total: 101 ms
# Wall time: 38.1 ms

# %% [markdown]
# # `pa.calc.add_xsnps()`

# %%
def add_xsnps(
    comid_type: str, 
    gdf: gpd.GeoDataFrame,
    df: pd.DataFrame,
) -> gpd.GeoDataFrame:
    """ Calculate excess non-point source pollution and add to the combined 
    PA2 results GeoDataFrame.
    
    excess nonpoint source pollution = excess pollution 
                                   – point source pollution

    Args:
        gdf: PA2 results GeoDataFrame with geometries for mapping 

    Returns:
        The input GeoDataFrame with three extra `_xs` columns added .
    """

    calc_suffix = 'xsnps'
    input_suffix = 'xs'

    if comid_type == 'reach':
        quantity_type = 'conc'
        ps_name = 'Point Source Derived Concentration'
    elif comid_type == 'catch':
        quantity_type = 'loadrate'
        ps_name = 'Point Sources'
    else:
        print("Error: comid_type must be 'reach' or 'catch'")

    df = select_run(comid_type, df, pa.calc.run_groups[0], ps=True)

    # for pollutant in pollutants.values():
    #     gdf[f'{pollutant}_{quantity_type}_{calc_suffix}'] = (
    #         gdf[f'{pollutant}_{quantity_type}'] 
    #         - targets[pollutant][f'{quantity_type}_target']
    #     )

    return df

# %%
add_xsnps('reach', reach_concs_gdf, reach_concs_df)

# %% [markdown]
# # `pa.calc.add_excess()`

# %%
# Open dictionary of Target Values
pa.calc.targets
# Out:
# {'tn': {'loadrate_target': 17.07, 'conc_target': 4.73},
#  'tp': {'loadrate_target': 0.31, 'conc_target': 0.09},
#  'tss': {'loadrate_target': 923.8, 'conc_target': 237.3}}

# %%
add_excess('catch', catch_loads_gdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aaufdenkampe/Documents/Python/pollution-assessment/stage2/sandbox.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/aaufdenkampe/Documents/Python/pollution-assessment/stage2/sandbox.ipynb#Y431sZmlsZQ%3D%3D?line=0'>1</a> add_excess('catch', catch_loads_gdf)
#
# NameError: name 'catch_loads_gdf' is not defined

# %% [markdown]
# # `pa.calc.add_loadrate()`

# %%
pa.calc.pollutants
# Out:
# {'TotalN': 'tn', 'TotalP': 'tp', 'Sediment': 'tss'}

# %%
pa.calc.pollutants['TotalP']
# Out:
# 'tp'

# %%
catch_loads_gdf = pa.calc.join_results('catch', catch_gdf, catch_loads_df, 
                                       pa.calc.run_groups[0], ps=False)

pa.calc.add_loadrate(catch_loads_gdf)
catch_loads_gdf
# Out:
#            catchment_hectares  watershed_hectares    maflowv  \
# comid
# 1748535             6496.7052             6501.69     43.699
# 1748537             1663.1712             1664.46     11.189
# 1748539             1639.4128             1640.70     11.223
# 1748541             3013.8348            12912.30     86.528
# 1748543             1151.0990             5232.87     35.389
# ...                       ...                 ...        ...
# 932040366           2124.7248          2720941.47  17802.923
# 932040367            788.7859          2717821.26  17788.281
# 932040368            265.0275          2716120.08  17780.448
# 932040369           1106.5294          2889095.67  18624.999
# 932040370           1531.4679          2891976.48  18637.381
#
#                                               geom_catchment cluster  \
# comid
# 1748535    MULTIPOLYGON (((-8301340.781 5199034.787, -830...     drb
# 1748537    MULTIPOLYGON (((-8304909.314 5200051.727, -830...     drb
# 1748539    MULTIPOLYGON (((-8315191.630 5191704.467, -831...     drb
# 1748541    MULTIPOLYGON (((-8309824.403 5193427.492, -830...     drb
# 1748543    MULTIPOLYGON (((-8312514.529 5185023.831, -831...     drb
# ...                                                      ...     ...
# 932040366  MULTIPOLYGON (((-8403944.327 4826463.781, -840...     drb
# 932040367  MULTIPOLYGON (((-8400739.269 4832000.931, -840...     drb
# 932040368  MULTIPOLYGON (((-8399608.027 4833463.133, -839...     drb
# 932040369  MULTIPOLYGON (((-8409371.984 4816335.622, -840...     drb
# 932040370  MULTIPOLYGON (((-8411052.928 4811112.367, -841...     drb
#
#            sub_focusarea   nord  nordstop         huc12  streamorder  ...  \
# comid                                                                 ...
# 1748535             <NA>  74914     74914  020401020302            1  ...
# 1748537             <NA>  74913     74913  020401020302            1  ...
# 1748539             <NA>  74921     74921  020401020305            1  ...
# 1748541             <NA>  74911     74915  020401020302            2  ...
# 1748543             <NA>  74920     74922  020401020305            2  ...
# ...                  ...    ...       ...           ...          ...  ...
# 932040366           <NA>  65070     76964  020402060103            7  ...
# 932040367           <NA>  65079     76964  020402060103            7  ...
# 932040368           <NA>  65080     76960  020402060103            7  ...
# 932040369           <NA>  64232     76965  020402040000            7  ...
# 932040370           <NA>  64226     76965  020402060105            7  ...
#
#                      Source      Sediment        TotalN       TotalP  \
# comid
# 1748535    Total Local Load  1.101612e+06  12680.544786  1189.608231
# 1748537    Total Local Load  2.013339e+05   3771.332143   363.366436
# 1748539    Total Local Load  2.514024e+05   3133.430355   357.227990
# 1748541    Total Local Load  6.177144e+05   6409.514442   668.969079
# 1748543    Total Local Load  1.989546e+05   2918.236825   317.461447
# ...                     ...           ...           ...          ...
# 932040366  Total Local Load  1.424324e+06  90140.391034  7976.492910
# 932040367  Total Local Load  4.208693e+05  20931.087768  1732.330415
# 932040368  Total Local Load  7.518927e+04    188.869267    19.006829
# 932040369  Total Local Load  2.122482e+06   1234.178951   222.587694
# 932040370  Total Local Load  1.607089e+06  20964.081525  2279.907784
#
#                               run_group  funding_sources  with_attenuation  \
# comid
# 1748535    No restoration or protection              NaN              True
# 1748537    No restoration or protection              NaN              True
# 1748539    No restoration or protection              NaN              True
# 1748541    No restoration or protection              NaN              True
# 1748543    No restoration or protection              NaN              True
# ...                                 ...              ...               ...
# 932040366  No restoration or protection              NaN              True
# 932040367  No restoration or protection              NaN              True
# 932040368  No restoration or protection              NaN              True
# 932040369  No restoration or protection              NaN              True
# 932040370  No restoration or protection              NaN              True
#
#           tn_loadrate tp_loadrate  tss_loadrate
# comid
# 1748535      1.951842    0.183109    169.564734
# 1748537      2.267555    0.218478    121.054237
# 1748539      1.911313    0.217900    153.349047
# 1748541      2.126697    0.221966    204.959595
# 1748543      2.535174    0.275790    172.838845
# ...               ...         ...           ...
# 932040366   42.424502    3.754130    670.356920
# 932040367   26.535829    2.196199    533.565995
# 932040368    0.712640    0.071716    283.703659
# 932040369    1.115360    0.201158   1918.143399
# 932040370   13.688881    1.488708   1049.378054
#
# [19496 rows x 23 columns]

# %%
warnings.filterwarnings(
    'ignore', 
    message='.*Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0.*'
)
warnings.filterwarnings(
    'ignore', 
    message='.*__len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0.*'
)

# %%
catch_loads_gdf.loc[4648450]
# Out:
# catchment_hectares                                             263.4373
# watershed_hectares                                               263.61
# maflowv                                                           1.412
# geom_catchment        (POLYGON ((-8449229.677149855 4880762.40560297...
# cluster                                        Brandywine and Christina
# sub_focusarea                                                      <NA>
# nord                                                              64639
# nordstop                                                          64639
# huc12                                                      020402050202
# streamorder                                                           1
# headwater                                                             1
# phase                                                           Phase 2
# fa_name                                     Brandywine Creek Headwaters
# Source                                                 Total Local Load
# Sediment                                                  190184.362667
# TotalN                                                      6679.866106
# TotalP                                                       409.449653
# run_group                                  No restoration or protection
# funding_sources                                                     NaN
# with_attenuation                                                   True
# tn_loadrate                                                   25.356569
# tp_loadrate                                                    1.554258
# tss_loadrate                                                 721.934072
# Name: 4648450, dtype: object

# %% [markdown]
# # `pa.calc.join_results()`

# %%
pa.calc.join_results('reach', reach_gdf, reach_concs_df, 
                     pa.calc.run_groups[0], ps=True)
# Out:
#            catchment_hectares  watershed_hectares    maflowv  \
# comid
# 1748535             6496.7052             6501.69     43.699
# 1748537             1663.1712             1664.46     11.189
# 1748539             1639.4128             1640.70     11.223
# 1748541             3013.8348            12912.30     86.528
# 1748543             1151.0990             5232.87     35.389
# ...                       ...                 ...        ...
# 932040366           2124.7248          2720941.47  17802.923
# 932040367            788.7859          2717821.26  17788.281
# 932040368            265.0275          2716120.08  17780.448
# 932040369           1106.5294          2889095.67  18624.999
# 932040370           1531.4679          2891976.48  18637.381
#
#                                                         geom cluster  \
# comid
# 1748535    MULTILINESTRING Z ((-8295323.930 5214456.622 0...     drb
# 1748537    MULTILINESTRING Z ((-8304623.226 5207684.737 0...     drb
# 1748539    MULTILINESTRING Z ((-8316446.558 5197994.113 0...     drb
# 1748541    MULTILINESTRING Z ((-8304282.841 5198049.613 0...     drb
# 1748543    MULTILINESTRING Z ((-8312991.936 5192442.779 0...     drb
# ...                                                      ...     ...
# 932040366  MULTILINESTRING Z ((-8400739.070 4831969.993 0...     drb
# 932040367  MULTILINESTRING Z ((-8399585.343 4833380.786 0...     drb
# 932040368  MULTILINESTRING Z ((-8398343.469 4834781.918 0...     drb
# 932040369  MULTILINESTRING Z ((-8406760.425 4820639.687 0...     drb
# 932040370  MULTILINESTRING Z ((-8409363.446 4816323.450 0...     drb
#
#            sub_focusarea   nord  nordstop         huc12  streamorder  \
# comid
# 1748535             <NA>  74914     74914  020401020302            1
# 1748537             <NA>  74913     74913  020401020302            1
# 1748539             <NA>  74921     74921  020401020305            1
# 1748541             <NA>  74911     74915  020401020302            2
# 1748543             <NA>  74920     74922  020401020305            2
# ...                  ...    ...       ...           ...          ...
# 932040366           <NA>  65070     76964  020402060103            7
# 932040367           <NA>  65079     76964  020402060103            7
# 932040368           <NA>  65080     76960  020402060103            7
# 932040369           <NA>  64232     76965  020402040000            7
# 932040370           <NA>  64226     76965  020402060105            7
#
#            headwater phase fa_name                              Source  \
# comid
# 1748535            1   NaN     NaN  Point Source Derived Concentration
# 1748537            1   NaN     NaN  Point Source Derived Concentration
# 1748539            1   NaN     NaN  Point Source Derived Concentration
# 1748541            0   NaN     NaN  Point Source Derived Concentration
# 1748543            0   NaN     NaN  Point Source Derived Concentration
# ...              ...   ...     ...                                 ...
# 932040366          0   NaN     NaN  Point Source Derived Concentration
# 932040367          0   NaN     NaN  Point Source Derived Concentration
# 932040368          0   NaN     NaN  Point Source Derived Concentration
# 932040369          0   NaN     NaN  Point Source Derived Concentration
# 932040370          0   NaN     NaN  Point Source Derived Concentration
#
#            Sediment  TotalN  TotalP                     run_group  \
# comid
# 1748535         0.0     0.0     0.0  No restoration or protection
# 1748537         0.0     0.0     0.0  No restoration or protection
# 1748539         0.0     0.0     0.0  No restoration or protection
# 1748541         0.0     0.0     0.0  No restoration or protection
# 1748543         0.0     0.0     0.0  No restoration or protection
# ...             ...     ...     ...                           ...
# 932040366       NaN     NaN     NaN  No restoration or protection
# 932040367       NaN     NaN     NaN  No restoration or protection
# 932040368       NaN     NaN     NaN  No restoration or protection
# 932040369       NaN     NaN     NaN  No restoration or protection
# 932040370       NaN     NaN     NaN  No restoration or protection
#
#           funding_sources  with_attenuation
# comid
# 1748535               NaN              True
# 1748537               NaN              True
# 1748539               NaN              True
# 1748541               NaN              True
# 1748543               NaN              True
# ...                   ...               ...
# 932040366             NaN              True
# 932040367             NaN              True
# 932040368             NaN              True
# 932040369             NaN              True
# 932040370             NaN              True
#
# [19496 rows x 20 columns]

# %%
pa.calc.join_results('catch', catch_gdf, catch_loads_df, 
                       pa.calc.run_groups[0], ps=False)
# Out:
#            catchment_hectares  watershed_hectares    maflowv  \
# comid
# 1748535             6496.7052             6501.69     43.699
# 1748537             1663.1712             1664.46     11.189
# 1748539             1639.4128             1640.70     11.223
# 1748541             3013.8348            12912.30     86.528
# 1748543             1151.0990             5232.87     35.389
# ...                       ...                 ...        ...
# 932040366           2124.7248          2720941.47  17802.923
# 932040367            788.7859          2717821.26  17788.281
# 932040368            265.0275          2716120.08  17780.448
# 932040369           1106.5294          2889095.67  18624.999
# 932040370           1531.4679          2891976.48  18637.381
#
#                                               geom_catchment cluster  \
# comid
# 1748535    MULTIPOLYGON (((-8301340.781 5199034.787, -830...     drb
# 1748537    MULTIPOLYGON (((-8304909.314 5200051.727, -830...     drb
# 1748539    MULTIPOLYGON (((-8315191.630 5191704.467, -831...     drb
# 1748541    MULTIPOLYGON (((-8309824.403 5193427.492, -830...     drb
# 1748543    MULTIPOLYGON (((-8312514.529 5185023.831, -831...     drb
# ...                                                      ...     ...
# 932040366  MULTIPOLYGON (((-8403944.327 4826463.781, -840...     drb
# 932040367  MULTIPOLYGON (((-8400739.269 4832000.931, -840...     drb
# 932040368  MULTIPOLYGON (((-8399608.027 4833463.133, -839...     drb
# 932040369  MULTIPOLYGON (((-8409371.984 4816335.622, -840...     drb
# 932040370  MULTIPOLYGON (((-8411052.928 4811112.367, -841...     drb
#
#            sub_focusarea   nord  nordstop         huc12  streamorder  \
# comid
# 1748535             <NA>  74914     74914  020401020302            1
# 1748537             <NA>  74913     74913  020401020302            1
# 1748539             <NA>  74921     74921  020401020305            1
# 1748541             <NA>  74911     74915  020401020302            2
# 1748543             <NA>  74920     74922  020401020305            2
# ...                  ...    ...       ...           ...          ...
# 932040366           <NA>  65070     76964  020402060103            7
# 932040367           <NA>  65079     76964  020402060103            7
# 932040368           <NA>  65080     76960  020402060103            7
# 932040369           <NA>  64232     76965  020402040000            7
# 932040370           <NA>  64226     76965  020402060105            7
#
#            headwater phase fa_name            Source      Sediment  \
# comid
# 1748535            1   NaN     NaN  Total Local Load  1.101612e+06
# 1748537            1   NaN     NaN  Total Local Load  2.013339e+05
# 1748539            1   NaN     NaN  Total Local Load  2.514024e+05
# 1748541            0   NaN     NaN  Total Local Load  6.177144e+05
# 1748543            0   NaN     NaN  Total Local Load  1.989546e+05
# ...              ...   ...     ...               ...           ...
# 932040366          0   NaN     NaN  Total Local Load  1.424324e+06
# 932040367          0   NaN     NaN  Total Local Load  4.208693e+05
# 932040368          0   NaN     NaN  Total Local Load  7.518927e+04
# 932040369          0   NaN     NaN  Total Local Load  2.122482e+06
# 932040370          0   NaN     NaN  Total Local Load  1.607089e+06
#
#                  TotalN       TotalP                     run_group  \
# comid
# 1748535    12680.544786  1189.608231  No restoration or protection
# 1748537     3771.332143   363.366436  No restoration or protection
# 1748539     3133.430355   357.227990  No restoration or protection
# 1748541     6409.514442   668.969079  No restoration or protection
# 1748543     2918.236825   317.461447  No restoration or protection
# ...                 ...          ...                           ...
# 932040366  90140.391034  7976.492910  No restoration or protection
# 932040367  20931.087768  1732.330415  No restoration or protection
# 932040368    188.869267    19.006829  No restoration or protection
# 932040369   1234.178951   222.587694  No restoration or protection
# 932040370  20964.081525  2279.907784  No restoration or protection
#
#           funding_sources  with_attenuation
# comid
# 1748535               NaN              True
# 1748537               NaN              True
# 1748539               NaN              True
# 1748541               NaN              True
# 1748543               NaN              True
# ...                   ...               ...
# 932040366             NaN              True
# 932040367             NaN              True
# 932040368             NaN              True
# 932040369             NaN              True
# 932040370             NaN              True
#
# [19496 rows x 20 columns]

# %% [markdown]
# # `pa.calc.select_run()`

# %%
pa.calc.run_groups
# Out:
# {0: 'No restoration or protection',
#  1: 'Direct WPF Restoration',
#  2: 'Direct and Indirect WPF Restoration',
#  3: 'All Restoration',
#  4: 'Direct WPF Protection'}

# %%
pa.calc.run_groups[0]
# Out:
# 'No restoration or protection'

# %%
for group in pa.calc.run_groups.values():
    print(group)
# Out:
# No restoration or protection
# Direct WPF Restoration
# Direct and Indirect WPF Restoration
# All Restoration
# Direct WPF Protection

# %%
pa.calc.select_run('catch', catch_loads_df, pa.calc.run_groups[0], ps=False)
# Out:
#                     Source       Sediment        TotalN       TotalP  \
# comid
# 2612780   Total Local Load   30060.129179    413.591250    39.349002
# 2612782   Total Local Load   62416.843740    941.392349    70.116676
# 2612792   Total Local Load   24783.144045    475.462392    56.373437
# 2612794   Total Local Load  504556.037460  10732.339874  1024.816694
# 2612920   Total Local Load  729581.146093   9437.277029   925.627843
# ...                    ...            ...           ...          ...
# 9891532   Total Local Load   20732.138827    319.088502    14.142305
# 10466473  Total Local Load   33825.045694     62.848284     3.391234
# 10466475  Total Local Load  157200.311620    321.131969    17.447391
# 10466691  Total Local Load    1225.353589      1.340191     0.146257
# 27081103  Total Local Load  481067.790337   4182.165423   207.875814
#
#                    huc gwlfe_endpoint  huc_level  \
# comid
# 2612780   020401010101       wikiSRAT         12
# 2612782   020401010101       wikiSRAT         12
# 2612792   020401010101       wikiSRAT         12
# 2612794   020401010101       wikiSRAT         12
# 2612920   020401010101       wikiSRAT         12
# ...                ...            ...        ...
# 9891532   020403040501       wikiSRAT         12
# 10466473  020403040501       wikiSRAT         12
# 10466475  020403040501       wikiSRAT         12
# 10466691  020403040501       wikiSRAT         12
# 27081103  020403040501       wikiSRAT         12
#
#                              run_group funding_sources  with_attenuation
# comid
# 2612780   No restoration or protection             NaN              True
# 2612782   No restoration or protection             NaN              True
# 2612792   No restoration or protection             NaN              True
# 2612794   No restoration or protection             NaN              True
# 2612920   No restoration or protection             NaN              True
# ...                                ...             ...               ...
# 9891532   No restoration or protection             NaN              True
# 10466473  No restoration or protection             NaN              True
# 10466475  No restoration or protection             NaN              True
# 10466691  No restoration or protection             NaN              True
# 27081103  No restoration or protection             NaN              True
#
# [21840 rows x 10 columns]

# %%
pa.calc.select_run('reach', reach_concs_df, pa.calc.run_groups[0], ps=True)
# Out:
#                                       Source  Sediment  TotalN  TotalP  \
# comid
# 2612780   Point Source Derived Concentration       0.0     0.0     0.0
# 2612782   Point Source Derived Concentration       0.0     0.0     0.0
# 2612792   Point Source Derived Concentration       0.0     0.0     0.0
# 2612794   Point Source Derived Concentration       0.0     0.0     0.0
# 2612920   Point Source Derived Concentration       0.0     0.0     0.0
# ...                                      ...       ...     ...     ...
# 9891532   Point Source Derived Concentration       0.0     0.0     0.0
# 10466473  Point Source Derived Concentration       0.0     0.0     0.0
# 10466475  Point Source Derived Concentration       0.0     0.0     0.0
# 10466691  Point Source Derived Concentration       0.0     0.0     0.0
# 27081103  Point Source Derived Concentration       0.0     0.0     0.0
#
#                    huc gwlfe_endpoint  huc_level  \
# comid
# 2612780   020401010101       wikiSRAT         12
# 2612782   020401010101       wikiSRAT         12
# 2612792   020401010101       wikiSRAT         12
# 2612794   020401010101       wikiSRAT         12
# 2612920   020401010101       wikiSRAT         12
# ...                ...            ...        ...
# 9891532   020403040501       wikiSRAT         12
# 10466473  020403040501       wikiSRAT         12
# 10466475  020403040501       wikiSRAT         12
# 10466691  020403040501       wikiSRAT         12
# 27081103  020403040501       wikiSRAT         12
#
#                              run_group funding_sources  with_attenuation
# comid
# 2612780   No restoration or protection             NaN              True
# 2612782   No restoration or protection             NaN              True
# 2612792   No restoration or protection             NaN              True
# 2612794   No restoration or protection             NaN              True
# 2612920   No restoration or protection             NaN              True
# ...                                ...             ...               ...
# 9891532   No restoration or protection             NaN              True
# 10466473  No restoration or protection             NaN              True
# 10466475  No restoration or protection             NaN              True
# 10466691  No restoration or protection             NaN              True
# 27081103  No restoration or protection             NaN              True
#
# [21840 rows x 10 columns]
